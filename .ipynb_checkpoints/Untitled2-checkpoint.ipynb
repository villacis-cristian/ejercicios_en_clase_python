# %% [markdown]
# # Examen del Tercer Parcial
# ## Regresión lineal
# Dado el archivo **movie_genre_classification_final.csv** se encuentra un base de datos con información de **50000 películas** que incluyen variables como: <br>
#  * Título,
#  * Año de estreno,
#  * Duración,
#  * Puntuación promedio,
#  * Número de votos,
#  * Presupuesto,
#  * Ingresos en taquilla,
#  * Número de premios obtenidos,
#  * Entre otras caracterisiticas.
# Como parate del análisis de predicción, se desea estudiar la relación entre el:<br>
# * Presupuesto de una película
# y sus caracteristicas cuantitativas, para estimar la **recaudación en taquilla (BoxOffice_USD)**. Para ello, se plantea entrenar un modelo de regresión lineal.<br>
#
# # Objetivo
# Predecir el valor de la variable **BoxOffice_USD** a partir de variables numéricas independientes disponibles en el dataset, tales como:<br>
# * Budget_USD (Presupuesto en dólares)
# * Duration (Duración en minutos)
# * Ratting (Calificiación Promedio"
# * Votes (Número de votos)
# * Num_Awards (Número de premios obtenidos)
# * Critic_reviews (Números de reseñas de criticos)
#
# El dataset fue extraido desder <a href="https://www.kaggle.com/datasets/therohithanand/movie-genre-classification">DataSet<a> <br>
#
# ## Entrega esperada
# * Código bien estructurado y comentado
# * Gráficos claros en los pasos 2, 4 y 5.
# * Breve análisis escrito de lso los resultados obtenidos.

# %% [markdown]
# # 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Cargar y preparar datos
df = pd.read_csv("movie_genre_classification_final.csv")
cols = ['Budget_USD', 'Duration', 'Rating', 'Votes', 'Num_Awards', 'Critic_Reviews', 'BoxOffice_USD']
df = df[cols].dropna()

# Aplicar logaritmo a variables con valores altos (evita aplastamiento visual)
df['log_BoxOffice'] = np.log1p(df['BoxOffice_USD'])  # log(1 + x) para evitar log(0)
df['log_Budget'] = np.log1p(df['Budget_USD'])
df['log_Votes'] = np.log1p(df['Votes'])
df['log_Awards'] = np.log1p(df['Num_Awards'])
df['log_Critics'] = np.log1p(df['Critic_Reviews'])

# Redefinir X y y
X = df[['log_Budget', 'Duration', 'Rating', 'log_Votes', 'log_Awards', 'log_Critics']]
y = df['log_BoxOffice']

# Escalar X
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train/Test
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Modelo
modelo = LinearRegression()
modelo.fit(X_train, y_train)

# Predicción
y_pred = modelo.predict(X_test)

# Inverso del logaritmo para interpretar resultados en dólares reales
y_test_real = np.expm1(y_test)
y_pred_real = np.expm1(y_pred)

# Evaluación
rmse = np.sqrt(mean_squared_error(y_test_real, y_pred_real))
r2 = r2_score(y_test_real, y_pred_real)

print(f"RMSE: {rmse:,.2f}")
print(f"R²: {r2:.2f}")

# Coeficientes
print("\nCoeficientes del modelo:")
for name, coef in zip(X.columns, modelo.coef_):
    print(f"{name}: {coef:.4f}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 10
#       7 warnings.filterwarnings("ignore")  # Para ignorar advertencias
#       9 # Cargamos el archivo CSV
# ---> 10 df = pd.read_csv("/mnt/data/movie_genre_classification_final.csv")
#      12 # Mostramos las primeras 5 filas del dataset
#      13 print("Primeras 5 filas del dataset:")
#
# ...

# %% [markdown]
# # 2

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=y_test_real, y=y_pred_real, alpha=0.4)
plt.plot([y_test_real.min(), y_test_real.max()], [y_test_real.min(), y_test_real.max()], '--r')
plt.xlabel("Recaudación real (USD)")
plt.ylabel("Recaudación predicha (USD)")
plt.title("Recaudación Real vs Predicha (deslogarítmicas)")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3

# %%
residuos = y_test_real - y_pred_real
plt.figure(figsize=(8,6))
sns.histplot(residuos, kde=True)
plt.axvline(0, color='red', linestyle='--')
plt.title("Distribución de residuos")
plt.xlabel("Error de predicción")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Predicciones
y_pred = modelo.predict(X_test)

# Métricas
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print(f"RMSE: {rmse:.2f}")
print(f"R²: {r2:.2f}")
# Out:
# RMSE: 289598062.20
# R²: -0.00

# %% [markdown]
# # 5

# %%
from sklearn.preprocessing import StandardScaler

# Escalar X
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Reentrenar con datos escalados
X_train_s, X_test_s, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)
modelo = LinearRegression()
modelo.fit(X_train_s, y_train)

# Predecir
y_pred = modelo.predict(X_test_s)

# Graficar resultados más realistas
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.4)
plt.plot([y.min(), y.max()], [y.min(), y.max()], '--r', label="Línea ideal")
plt.xlabel("Recaudación real (USD)")
plt.ylabel("Recaudación predicha (USD)")
plt.title("Real vs Predicho - Recaudación (con datos escalados)")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # 6

# %% [markdown]
# # 7
